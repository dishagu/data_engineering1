# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
matchdf= pd.read_csv("C:\\Users\\Harshita\\Documents\\BigDataFiles\\CSV_files\\match_summary.csv")

# %%
matchdf
# Out:
#          Team 1       Team 2     Winner     Margin           Ground  \
# 0     Australia        India  Australia    12 runs           Sydney
# 1     Australia        India      India  6 wickets           Sydney
# 2     Australia        India      India    11 runs         Canberra
# 3   New Zealand        India      India     7 runs  Mount Maunganui
# 4   New Zealand        India       tied          -       Wellington
# ..          ...          ...        ...        ...              ...
# 76        India     Pakistan      India     6 runs         New York
# 77        India      Ireland      India  8 wickets         New York
# 78        India  Afghanistan       tied          -        Bengaluru
# 79        India  Afghanistan      India  6 wickets           Indore
# 80        India  Afghanistan      India  6 wickets           Mohali
#
#       Match Date    Scorecard  \
# 0    Dec 8, 2020  T20I # 1116
# 1    Dec 6, 2020  T20I # 1115
# 2    Dec 4, 2020  T20I # 1114
# ...

# %%
matchdf['Ground'] = matchdf['Ground'].str.replace(' ', '')
matchdf.head()
# Out:
#         Team 1 Team 2     Winner     Margin          Ground    Match Date  \
# 0    Australia  India  Australia    12 runs          Sydney   Dec 8, 2020
# 1    Australia  India      India  6 wickets          Sydney   Dec 6, 2020
# 2    Australia  India      India    11 runs        Canberra   Dec 4, 2020
# 3  New Zealand  India      India     7 runs  MountMaunganui   Feb 2, 2020
# 4  New Zealand  India       tied          -      Wellington  Jan 31, 2020
#
#      Scorecard                                     Scorecard Link  Match_id
# 0  T20I # 1116  https://www.espncricinfo.com/series/india-in-a...      1116
# 1  T20I # 1115  https://www.espncricinfo.com/series/india-in-a...      1115
# 2  T20I # 1114  https://www.espncricinfo.com/series/india-in-a...      1114
# 3  T20I # 1037  https://www.espncricinfo.com/series/india-in-n...      1037
# 4  T20I # 1036  https://www.espncricinfo.com/series/india-in-n...      1036

# %%
groundinfo=pd.read_csv("C:\\Users\\Harshita\\Downloads\\GroundDetails.csv")

# %%
matchdf.rename(columns={
    'Team 1': 'Team1',
    'Team 2': 'Team2',
    'Winner': 'Winner',
    'Margin': 'Margin',
    'Ground': 'Ground',
    'Match Date': 'MatchDate',
    'Scorecard': 'Scorecard',
    'Scorecard Link': 'ScorecardLink',
    'Match_id': 'MatchID'
}, inplace=True)

# %%
groundinfo
# Out:
#                                            GroundName          Established  \
# 0                               Sydney Cricket Ground                 1848
# 1                                         Manuka Oval                 1929
# 2                                            Bay Oval                 2007
# 3                                         Sky Stadium                 1999
# 4                                         Seddon Park                 1950
# 5                                           Eden Park                 1900
# 6             Maharashtra Cricket Association Stadium                  NaN
# 7                              Holkar Cricket Stadium                  NaN
# 8                           Barsapara Cricket Stadium                 2012
# 9                                        Eden Gardens                 1864
# 10                 JSCA International Stadium Complex                  NaN
# ...

# %%
matchdf
# Out:
#           Team1        Team2     Winner     Margin          Ground  \
# 0     Australia        India  Australia    12 runs          Sydney
# 1     Australia        India      India  6 wickets          Sydney
# 2     Australia        India      India    11 runs        Canberra
# 3   New Zealand        India      India     7 runs  MountMaunganui
# 4   New Zealand        India       tied          -      Wellington
# ..          ...          ...        ...        ...             ...
# 76        India     Pakistan      India     6 runs         NewYork
# 77        India      Ireland      India  8 wickets         NewYork
# 78        India  Afghanistan       tied          -       Bengaluru
# 79        India  Afghanistan      India  6 wickets          Indore
# 80        India  Afghanistan      India  6 wickets          Mohali
#
#        MatchDate    Scorecard  \
# 0    Dec 8, 2020  T20I # 1116
# 1    Dec 6, 2020  T20I # 1115
# 2    Dec 4, 2020  T20I # 1114
# 3    Feb 2, 2020  T20I # 1037
# ...

# %%
matchdf
# Out:
#           Team1        Team2     Winner     Margin          Ground  \
# 0     Australia        India  Australia    12 runs          Sydney
# 1     Australia        India      India  6 wickets          Sydney
# 2     Australia        India      India    11 runs        Canberra
# 3   New Zealand        India      India     7 runs  MountMaunganui
# 4   New Zealand        India       tied          -      Wellington
# ..          ...          ...        ...        ...             ...
# 76        India     Pakistan      India     6 runs         NewYork
# 77        India      Ireland      India  8 wickets         NewYork
# 78        India  Afghanistan       tied          -       Bengaluru
# 79        India  Afghanistan      India  6 wickets          Indore
# 80        India  Afghanistan      India  6 wickets          Mohali
#
#        MatchDate    Scorecard  \
# 0    Dec 8, 2020  T20I # 1116
# 1    Dec 6, 2020  T20I # 1115
# 2    Dec 4, 2020  T20I # 1114
# 3    Feb 2, 2020  T20I # 1037
# ...

# %%
# Create a dictionary to map ground names to ground IDs
mapping = dict(zip(groundinfo['GroundCity'], groundinfo['GroundID']))
print(mapping)
# Out:
# {'Sydney': 1, 'Canberra': 2, 'MountMaunganui': 3, 'Wellington': 4, 'Hamilton': 5, 'Auckland': 6, 'Pune': 7, 'Indore': 8, 'Guwahati': 9, 'EdenGardens': 10, 'Ranchi': 11, 'Jaipur': 12, 'Dubai(DICS)': 13, 'AbuDhabi': 14, 'Colombo(RPS)': 15, 'Ahmedabad': 16, 'Napier': 17, 'Adelaide': 18, 'Melbourne': 19, 'Perth': 20, 'Thiruvananthapuram': 21, 'Hyderabad': 22, 'Nagpur': 23, 'Mohali': 24, 'Lauderhill': 25, 'Basseterre': 26, 'Tarouba': 27, 'Nottingham': 28, 'Birmingham': 29, 'Southampton': 30, 'Dublin(Malahide)': 31, 'Bengaluru': 32, 'Rajkot': 33, 'Visakhapatnam': 34, 'Cuttack': 35, 'Delhi': 36, 'Dharamsala': 37, 'Lucknow': 38, 'Harare': 39, 'Bridgetown': 40, 'Providence': 41, 'GrosIslet': 42, 'NorthSound': 43, 'NewYork': 44}

# %%
# Assign ground_id_id to each player based on the country
matchdf['GroundID'] = matchdf['Ground'].map(mapping)

# %%
matchdf
# Out:
#           Team1        Team2     Winner     Margin          Ground  \
# 0     Australia        India  Australia    12 runs          Sydney
# 1     Australia        India      India  6 wickets          Sydney
# 2     Australia        India      India    11 runs        Canberra
# 3   New Zealand        India      India     7 runs  MountMaunganui
# 4   New Zealand        India       tied          -      Wellington
# ..          ...          ...        ...        ...             ...
# 76        India     Pakistan      India     6 runs         NewYork
# 77        India      Ireland      India  8 wickets         NewYork
# 78        India  Afghanistan       tied          -       Bengaluru
# 79        India  Afghanistan      India  6 wickets          Indore
# 80        India  Afghanistan      India  6 wickets          Mohali
#
#        MatchDate    Scorecard  \
# 0    Dec 8, 2020  T20I # 1116
# 1    Dec 6, 2020  T20I # 1115
# 2    Dec 4, 2020  T20I # 1114
# 3    Feb 2, 2020  T20I # 1037
# ...

# %% [markdown]
# groundid ----many null values

# %%
csv_file_path = 'matchsummary.csv'
matchdf.to_csv(csv_file_path, index=False)
